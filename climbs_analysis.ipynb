# %%
import pandas as pd

# %%
df = pd.read_csv('./out/climbs.csv')
df.head()
# Out:
#                                uuid  layout_id  setter_id  \
# 0  002047402B6941CEA5ED7BB09FBFE14D          1       1051
# 1  002ED50792A94E5EB2127D59E167B2EE          1      17760
# 2  003FF8E4DA8448E39696635E6DBD7B7C          1       8494
# 3  004FB7A0C0754DA98634C5EE4D985D9A          1      45676
# 4  00683d10a8e246b3a106531c8573f13c          1      44916
#
#        setter_username                           name  \
# 0         kilterjackie  4/26 Harder Than It Should Be
# 1              bctyner          what kind of triangle
# 2  progressionclimbing            this is a statement
# 3            jefferoni                 SpEeD cLiMbInG
# 4          mark.nalder                    marks 1 try
#
#                                 description  hsm  edge_left  edge_right  \
# 0                                       NaN    3         40         136
# 1  Make sure you angle your body just right    3          4         140
# ...

# %%
df[(df['setter_username'] == 'iruven')]
# Out:
#                                     uuid  layout_id  setter_id  \
# 304194  1645fe0ce89b44039f3b13a02da45ffd          1     548269
#
#        setter_username               name description  hsm  edge_left  \
# 304194          iruven  drabina stupkarza         NaN    3         80
#
#         edge_right  edge_bottom  edge_top  angle  frames_count  frames_pace  \
# 304194         140            8       152   35.0             1            0
#
#                                                    frames  is_draft  \
# 304194  p1073r15p1077r15p1169r12p1189r12p1235r13p1256r...         0
#
#         is_listed                  created_at  is_nomatch
# 304194          1  2025-07-12 10:10:13.971235           0

# %%
df_climb_stats = pd.read_csv('./out/climb_stats.csv')
df_climb_stats[(df_climb_stats['fa_username'] == 'iruven')]
# Out:
#                               climb_uuid  angle  display_difficulty  \
# 289892  1645fe0ce89b44039f3b13a02da45ffd     35                17.0
#
#         benchmark_difficulty  ascensionist_count  difficulty_average  \
# 289892                   NaN                   2                17.0
#
#         quality_average fa_username                fa_at
# 289892              3.0      iruven  2025-08-25 11:53:46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313774 entries, 0 to 313773
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   uuid             313774 non-null  object
#  1   layout_id        313774 non-null  int64
#  2   setter_id        313774 non-null  int64
#  3   setter_username  313774 non-null  object
#  4   name             313770 non-null  object
#  5   description      109557 non-null  object
#  6   hsm              313774 non-null  int64
#  7   edge_left        313774 non-null  int64
#  8   edge_right       313774 non-null  int64
#  9   edge_bottom      313774 non-null  int64
#  10  edge_top         313774 non-null  int64
#  11  angle            210200 non-null  float64
#  12  frames_count     313774 non-null  int64
#  13  frames_pace      313774 non-null  int64
#  14  frames           313774 non-null  object
#  15  is_draft         313774 non-null  int64
# ...

# %%
df_merged = pd.merge(df, df_climb_stats,how='inner', left_on='uuid', right_on='climb_uuid')
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319436 entries, 0 to 319435
# Data columns (total 28 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   uuid                  319436 non-null  object
#  1   layout_id             319436 non-null  int64
#  2   setter_id             319436 non-null  int64
#  3   setter_username       319436 non-null  object
#  4   name                  319433 non-null  object
#  5   description           110197 non-null  object
#  6   hsm                   319436 non-null  int64
#  7   edge_left             319436 non-null  int64
#  8   edge_right            319436 non-null  int64
#  9   edge_bottom           319436 non-null  int64
#  10  edge_top              319436 non-null  int64
#  11  angle_x               172649 non-null  float64
#  12  frames_count          319436 non-null  int64
#  13  frames_pace           319436 non-null  int64
# ...

# %%
df_merged[df_merged['ascensionist_count'] == max(df_merged['ascensionist_count'])]
# Out:
#                                    uuid  layout_id  setter_id setter_username  \
# 63057  AC9FCF7F01FC44BD835CFC41CB2224DA          1       3174        JustinKo
#
#                     name description  hsm  edge_left  edge_right  edge_bottom  \
# 63057  You Don’t Know Me         NaN    1         56         112           16
#
#        ...  is_nomatch                        climb_uuid  angle_y  \
# 63057  ...           0  AC9FCF7F01FC44BD835CFC41CB2224DA       40
#
#        display_difficulty benchmark_difficulty  ascensionist_count  \
# 63057             15.9962                  NaN               69140
#
#        difficulty_average quality_average  fa_username                fa_at
# 63057             15.9962         2.95499     JustinKo  2019-02-18 22:46:20
#
# [1 rows x 28 columns]
